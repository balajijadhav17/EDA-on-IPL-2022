# %%
import pandas as pd

# %%
df=pd.read_csv("education_COVID-19.csv")
df
# Out:
#     Country Code      Country Name     Dt Extraction  \
# 0            ERI           Eritrea  07-07-2020 03:28
# 1            GNB     Guinea-Bissau  07-07-2020 03:28
# 2            SMR        San Marino  07-07-2020 03:28
# 3            GEO           Georgia  07-07-2020 03:28
# 4            ITA             Italy  07-07-2020 03:28
# ..           ...               ...               ...
# 196          MAC  Macao SAR, China  07-07-2020 03:28
# 197          NRU             Nauru  07-07-2020 03:28
# 198          SLB   Solomon Islands  07-07-2020 03:28
# 199          VUT           Vanuatu  07-07-2020 03:28
# 200          WSM             Samoa  07-07-2020 03:28
#
#     If Closed Due To COVID19 When         Income Level  \
# 0                             NaN           Low income
# 1                             NaN           Low income
# 2                   01 March 2020          High income
# 3                   03 March 2020  Upper middle income
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country Code                   199 non-null    object
#  1   Country Name                   200 non-null    object
#  2   Dt Extraction                  201 non-null    object
#  3   If Closed Due To COVID19 When  183 non-null    object
#  4   Income Level                   197 non-null    object
#  5   Region Name                    197 non-null    object
#  6   School Status                  201 non-null    object
#  7   Year Pre                       197 non-null    float64
#  8   Year Prm                       197 non-null    float64
#  9   Year Sec                       197 non-null    float64
#  10  Year Ter                       192 non-null    float64
#  11  Latitude                       198 non-null    float64
# ...
